// %% [markdown]
// # Java Notebook
// >My Java Jupyter Notebook
// - toc: true
// - categories: [fastpages, jupyter]

// %%
public class Hello {
    public static void main(String[] args) {
        System.out.println("Hello World!");
    }
}

Hello.main(null);
// Out:
// Hello World!
